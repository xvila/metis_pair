# %%
import pandas as pd
import statsmodels.api as sm
#import statsmodels.formula.api as smf
import statsmodels.api as smf
import patsy
import seaborn as sns
sns.set_style("darkgrid")
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dict = {}
for i in range(1,numFeatures+1):
    dict[i] = np.random.normal(0,1,200)

# %%
numFeatures = 40

# %%
#dict

# %%
 y = np.random.normal(0,1,200)

# %%
y
# Out:
# array([ 0.86814813,  0.46672447, -1.12665   ,  0.17489624, -0.07712707,
#        -0.20512435, -0.29551474,  0.2226145 ,  1.03095197, -1.01854809,
#         0.21242596, -0.64586105,  0.22768418, -0.72864999,  1.54605912,
#        -0.1253658 ,  0.64942577,  0.56869261, -0.37840635, -0.28412803,
#         0.63308993,  0.67265464, -0.16590746, -0.32357385,  0.95165068,
#         0.64191263, -0.868789  ,  0.44695403, -0.39192039, -1.02329574,
#         0.02152049,  0.20286001, -1.53114817, -0.30908991,  1.42623325,
#         0.35466778,  0.29575312,  0.52587516, -0.73696286,  0.2317473 ,
#        -0.35417092, -2.41981671, -1.05749337, -0.60454067,  0.59970421,
#        -0.5948401 , -0.20719409,  1.02045324,  0.0759588 ,  1.70728233,
#         0.31900479,  0.28182981, -0.71103309, -1.7417842 , -0.94056859,
#         0.7499947 , -0.79506075,  1.58552018,  1.18343264,  0.7732431 ,
#        -0.84944676, -0.57311769,  2.10105228,  0.12933021, -0.96848352,
# ...

# %%
df = pd.DataFrame.from_dict(dict)

# %%
y = pd.DataFrame(y)

# %%
df = df.merge(y,left_index=True,right_index=True)

# %%
y.tail()
# Out:
#             0
# 195 -0.698702
# 196 -0.467267
# 197 -0.310572
# 198 -1.649108
# 199  0.302830

# %%
df
# Out:
#            1         2         3         4         5         6         7   \
# 0    0.832207  1.062880 -0.865855 -0.544190  0.359792  0.599411 -2.411312
# 1    0.353739 -1.216969  0.591980  0.789449 -0.266167 -0.580279 -0.835265
# 2   -0.247490 -1.048823 -1.139279 -0.354447 -0.237559 -2.265492  0.370245
# 3   -0.026606 -1.152237  0.579859  0.266822 -0.690657  0.555361  1.702891
# 4    0.126196  0.152989 -2.025495 -0.356061  0.501537  0.746777  0.420037
# 5   -0.021664  1.327987  0.455242  0.852212 -0.360723 -0.083547  0.437172
# 6    0.091936 -0.405265  1.490184 -0.676172  1.922331 -1.508563 -1.358855
# 7   -1.199395 -0.154042  1.732926 -0.318894 -2.512555 -0.797095 -0.405535
# 8   -0.424451  0.612981  0.282678  0.879168  0.104368 -0.678777  0.154829
# 9    1.371067 -1.177530 -0.874595  0.159218  0.315110 -1.104535 -0.469565
# 10  -0.314615 -1.949917 -0.641888  0.326224 -0.696633 -0.434363 -0.330792
# 11   0.221109 -0.051798 -0.681822 -0.504185  1.629812  0.545959 -1.570345
# ...

# %%
#df.drop('0_x',inplace=True,axis=1)

# %%
df.head()
# Out:
#          1         2         3         4         5         6         7   \
# 0  0.832207  1.062880 -0.865855 -0.544190  0.359792  0.599411 -2.411312
# 1  0.353739 -1.216969  0.591980  0.789449 -0.266167 -0.580279 -0.835265
# 2 -0.247490 -1.048823 -1.139279 -0.354447 -0.237559 -2.265492  0.370245
# 3 -0.026606 -1.152237  0.579859  0.266822 -0.690657  0.555361  1.702891
# 4  0.126196  0.152989 -2.025495 -0.356061  0.501537  0.746777  0.420037
#
#          8         9         10    ...           32        33        34  \
# 0 -1.112970 -2.214235 -0.364097    ...     0.545084  0.875784  1.206036
# 1  0.374167  0.834553 -0.413987    ...     1.468766  0.348843  0.705041
# 2  0.750393  1.404158  0.611300    ...    -0.143580  1.190213 -0.242112
# 3  0.572228  0.072090 -1.789903    ...    -0.427500 -0.655133 -0.037709
# 4  0.798858 -1.118903  0.609733    ...     1.173195  1.612375  0.081813
#
#          35        36        37        38        39        40        0
# ...

# %%
#df.drop(0,inplace=True,axis=1)

# %%
df.head()
# Out:
#          1         2         3         4         5         6         7   \
# 0  0.832207  1.062880 -0.865855 -0.544190  0.359792  0.599411 -2.411312
# 1  0.353739 -1.216969  0.591980  0.789449 -0.266167 -0.580279 -0.835265
# 2 -0.247490 -1.048823 -1.139279 -0.354447 -0.237559 -2.265492  0.370245
# 3 -0.026606 -1.152237  0.579859  0.266822 -0.690657  0.555361  1.702891
# 4  0.126196  0.152989 -2.025495 -0.356061  0.501537  0.746777  0.420037
#
#          8         9         10    ...           32        33        34  \
# 0 -1.112970 -2.214235 -0.364097    ...     0.545084  0.875784  1.206036
# 1  0.374167  0.834553 -0.413987    ...     1.468766  0.348843  0.705041
# 2  0.750393  1.404158  0.611300    ...    -0.143580  1.190213 -0.242112
# 3  0.572228  0.072090 -1.789903    ...    -0.427500 -0.655133 -0.037709
# 4  0.798858 -1.118903  0.609733    ...     1.173195  1.612375  0.081813
#
#          35        36        37        38        39        40        0
# ...

# %%
df.columns=['X_%i' %i for i in range(1,len(df.columns)+1)  ]
#['Score_%i' % i for i in xrange(1, len(cols[2:])+1)]

# %%
df.columns
# Out:
# Index(['X_1', 'X_2', 'X_3', 'X_4', 'X_5', 'X_6', 'X_7', 'X_8', 'X_9', 'X_10',
#        'X_11', 'X_12', 'X_13', 'X_14', 'X_15', 'X_16', 'X_17', 'X_18', 'X_19',
#        'X_20', 'X_21', 'X_22', 'X_23', 'X_24', 'X_25', 'X_26', 'X_27', 'X_28',
#        'X_29', 'X_30', 'X_31', 'X_32', 'X_33', 'X_34', 'X_35', 'X_36', 'X_37',
#        'X_38', 'X_39', 'X_40', 'X_41'],
#       dtype='object')

# %%
df.rename(columns={"X_41":"Y"}, inplace=True)

# %%
df.head()
# Out:
#         X_1       X_2       X_3       X_4       X_5       X_6       X_7  \
# 0  0.832207  1.062880 -0.865855 -0.544190  0.359792  0.599411 -2.411312
# 1  0.353739 -1.216969  0.591980  0.789449 -0.266167 -0.580279 -0.835265
# 2 -0.247490 -1.048823 -1.139279 -0.354447 -0.237559 -2.265492  0.370245
# 3 -0.026606 -1.152237  0.579859  0.266822 -0.690657  0.555361  1.702891
# 4  0.126196  0.152989 -2.025495 -0.356061  0.501537  0.746777  0.420037
#
#         X_8       X_9      X_10    ...         X_32      X_33      X_34  \
# 0 -1.112970 -2.214235 -0.364097    ...     0.545084  0.875784  1.206036
# 1  0.374167  0.834553 -0.413987    ...     1.468766  0.348843  0.705041
# 2  0.750393  1.404158  0.611300    ...    -0.143580  1.190213 -0.242112
# 3  0.572228  0.072090 -1.789903    ...    -0.427500 -0.655133 -0.037709
# 4  0.798858 -1.118903  0.609733    ...     1.173195  1.612375  0.081813
#
#        X_35      X_36      X_37      X_38      X_39      X_40         Y
# ...

# %%
# y, X = patsy.dmatrices('Y ~ X_1 + X_2 + X_3 + X_4 + X_5 + X_6 + X_7 + X_8 + X_9 + X_10', data=df, return_type='dataframe')
# model = sm.OLS(y,X)
# fit = model.fit()
# fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.110
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     2.330
# Date:                Thu, 28 Sep 2017   Prob (F-statistic):             0.0130
# Time:                        10:11:14   Log-Likelihood:                -271.75
# No. Observations:                 200   AIC:                             565.5
# Df Residuals:                     189   BIC:                             601.8
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1193      0.070      1.692      0.092      -0.020       0.258
# ...

# %%
mstring = ''
for i in range(1,numFeatures+1):
    mstring += 'X_%i + ' % i

# %%
mstring = mstring.strip(' +')

# %%
y2, X2 = patsy.dmatrices('Y ~ ' +  mstring, data=df, return_type='dataframe')
model2 = sm.OLS(y2,X2)
fit2 = model2.fit()
fit2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.158
# Model:                            OLS   Adj. R-squared:                 -0.053
# Method:                 Least Squares   F-statistic:                    0.7479
# Date:                Thu, 28 Sep 2017   Prob (F-statistic):              0.859
# Time:                        10:19:55   Log-Likelihood:                -255.92
# No. Observations:                 200   AIC:                             593.8
# Df Residuals:                     159   BIC:                             729.1
# Df Model:                          40
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0789      0.076      1.036      0.302      -0.071       0.229
# ...
